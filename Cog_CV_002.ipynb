# %%
import cv2
from google.colab.patches import cv2_imshow
# !ls
# Out:
# sample_data  tetris.jpg

# %%
img = cv2.imread('tetris.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=626x400 at 0x7F4DEE946E90>

# %%
img2 = img.copy()
cv2.circle(img2, (150,150), 20, (0,0,255),-1) # BGR-> default 
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=626x400 at 0x7F4DE503A390>

# %%
cv2.line(img2, (30,30), (500,42), (255,0,0), 3 )
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=626x400 at 0x7F4DDF805610>

# %%
img3 = img.copy()
cv2.line(img3, (100,100), (200,42), (25,10,90), 3 )
cv2.line(img3, (200,42), (300,192), (2,60,30), 3 )
cv2.line(img3, (300,192), (100,100), (255,255,30), 3 )

cv2.putText(img3, "Tetris can be fun", (10,30), cv2.FONT_HERSHEY_COMPLEX, 0.7, (0,255,0), 3)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=626x400 at 0x7F4DE4015750>

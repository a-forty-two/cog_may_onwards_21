# %%
# VGG=> Convolutions-> 1D, 2D
# Image Processing and Computer Vision
# IP-> opening an image as an array 
# transformation, filters, blurring 

# Computer Vision-> Continous input of vision data
# RGB, infrared, CMY, RGBA, BGR

# Smart Car=> selfdriving car
# DL model to detect humans on road
# 100 mph-> person comes on road-> DL model -> F1/Accuracy-> 500ms 

# Infrared Sensor-> input stream-> obstruction in IR reflection-> stop the car 
# computer vision 

# image-> detect object, activity-> continous stream of images

# %%
# !ls
# Out:
# 122.jpg  sample_data

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('122.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x7F7866C2CB50>

# %%
import numpy as np
imgarray = np.array(img)
len(imgarray)
# Out:
# 675

# %%
imgarray.shape
# Out:
# (675, 1200, 3)

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
import matplotlib.pyplot as plt
plt.imshow(img2, cmap='gray')
# different SCALE!

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
import matplotlib.pyplot as plt
plt.imshow(img2, cmap='Greys')
# this is a #3D vector

# %%
img3 = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x7F78652EF310>

# %%
# SINGLE color filters:
# SPace photography-> COLOR-> black-> light is lost
# Infrared-> scale them to RGB-> then present to us!
# GREEN-> object
B,G,R = cv2.split(img)
filter = [0,1,0]
imgx = cv2.merge([B*filter[0], G*filter[1], R**filter[2]])

# %%
plt.imshow(imgx, cmap='Greys')

# %%
plt.figure()
plt.imshow(G, cmap='gray')
